# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("car_purchasing.csv", encoding="latin-1")

# %%
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
data.shape
# Out:
# (500, 9)

# %%
data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
data[['age','annual Salary', 'credit card debt', 'net worth','car purchase amount']].corr()["car purchase amount"].head(1)
# Out:
# age    0.632865
# Name: car purchase amount, dtype: float64

# %%
plt.scatter(data['age'],data['car purchase amount'])
plt.title("Age and Purchase Amount")
plt.xlabel("Age")
plt.ylabel("Car Purchase Amount")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data['annual Salary'],data['car purchase amount'])
plt.title("annual Salary and Purchase Amount")
plt.xlabel("annual Salary")
plt.ylabel("Car Purchase Amount")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data['net worth'],data['car purchase amount'])
plt.title("net worth and Purchase Amount")
plt.xlabel("net worth")
plt.ylabel("Car Purchase Amount")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data['credit card debt'],data['car purchase amount'])
plt.title("Debt and Purchase Amount")
plt.xlabel("Debt")
plt.ylabel("Car Purchase Amount")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data[data["country"]=="Turkey"]
# Out:
#       customer name                                   customer e-mail country  \
# 37   Uriel Bradshaw                       ultrices@Integersemelit.com  Turkey
# 40    Rachel Ashley  tincidunt.tempus.risus@posuerecubiliaCurae.co.uk  Turkey
# 477        Isabella                             et.magnis@necmetus.ca  Turkey
#
#      gender        age  annual Salary  credit card debt    net worth  \
# 37        1  22.000387    43131.78411      10917.140940  326742.7352
# 40        0  42.449786    66417.66597       9183.327621  513340.0097
# 477       1  40.754052    60101.79725      12989.367840  340720.5185
#
#      car purchase amount
# 37           10092.22509
# 40           45805.67186
# 477          35823.55471

# %%
data["country"].unique()
# Out:
# array(['Bulgaria', 'Belize', 'Algeria', 'Cook Islands', 'Brazil',
#        'Liberia', 'Syria', 'Czech Republic', 'Armenia', 'Somalia',
#        'Sint Maarten', 'Greenland', 'Nicaragua', 'Palestine, State of',
#        'United Arab Emirates', 'Gabon', 'Tokelau', 'Portugal', 'Chad',
#        'Iraq', 'Sudan', 'Angola', 'Nigeria', 'Madagascar', 'Macedonia',
#        'Oman', 'Colombia', 'Namibia', 'Denmark', 'Dominican Republic',
#        'Costa Rica', 'Botswana', 'Saint Pierre and Miquelon', 'France',
#        'Senegal', 'Cambodia', 'Suriname', 'Turkey', 'Ethiopia',
#        'French Guiana', 'Bhutan', 'Georgia', 'Mozambique', 'Nauru',
#        'Timor-Leste', 'Djibouti', 'Argentina', 'Taiwan', 'Åland Islands',
#        'Turks and Caicos Islands', 'Samoa', 'Vanuatu', 'Mongolia',
#        'Sri Lanka', 'Guinea-Bissau', 'Egypt', 'Slovenia', 'Benin',
#        'Cape Verde', 'Paraguay', 'Laos', 'Iceland', 'Viet Nam',
#        'Marshall Islands', 'Germany', 'Kyrgyzstan', 'Mauritius', 'Gambia',
# ...

# %%
# For adding new column in the dataset 
data["gender2"] = data["gender"].apply(lambda x: "Female" if x==1 else "Male")

# %%
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
data["gender2"].value_counts()
# Out:
# gender2
# Female    253
# Male      247
# Name: count, dtype: int64

# %%
data.groupby("gender2")["age"].max()
# Out:
# gender2
# Female    69.569306
# Male      70.000000
# Name: age, dtype: float64

# %%
data.groupby("gender2")["age"].min()
# Out:
# gender2
# Female    20.000000
# Male      25.179893
# Name: age, dtype: float64

# %%
data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth', 'car purchase amount',
#        'gender2'],
#       dtype='object')

# %%
data.groupby("gender2")["annual Salary"].mean()
# Out:
# gender2
# Female    61705.593322
# Male      62559.128313
# Name: annual Salary, dtype: float64

# %%
data.groupby("gender2")["net worth"].mean()
# Out:
# gender2
# Female    430037.639104
# Male      432948.721130
# Name: net worth, dtype: float64

# %%
data.groupby("gender2")["net worth"].mean().plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("Net Worth")
plt.title("Networth by Gender")
plt.show()

# %%
data["age"]
# Out:
# 0      41.851720
# 1      40.870623
# 2      43.152897
# 3      58.271369
# 4      57.313749
#          ...
# 495    41.462515
# 496    37.642000
# 497    53.943497
# 498    59.160509
# 499    46.731152
# Name: age, Length: 500, dtype: float64

# %%
# set the age range
def age_groups_creation(row):
    if row["age"] < 30:
        return "20 - 30 "
    elif row["age"] < 40:
        return "30 - 40"
    elif row["age"] < 50:
        return "40 - 50"
    elif row["age"] < 60:
        return "50 - 60"
    else:
        return "60 - 70"

# %%
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
# make a another column of age range
data["Age Ranges"]= data.apply(age_groups_creation, axis=1)

# %%
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
data["age"]
# Out:
# 0      41.851720
# 1      40.870623
# 2      43.152897
# 3      58.271369
# 4      57.313749
#          ...
# 495    41.462515
# 496    37.642000
# 497    53.943497
# 498    59.160509
# 499    46.731152
# Name: age, Length: 500, dtype: float64

# %%
plt.hist(data["age"])
plt.xlabel("age")
plt.ylabel("frequency")
plt.title("Histogram of Age")
plt.show()

# %%
data["Age Ranges"].value_counts()
# Out:
# Age Ranges
# 40 - 50     231
# 50 - 60     142
# 30 - 40      96
# 60 - 70      23
# 20 - 30       8
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth', 'car purchase amount',
#        'gender2', 'Age Ranges'],
#       dtype='object')

# %%
data.groupby("Age Ranges")["annual Salary"].mean().plot(kind="bar")
plt.xlabel("Age Range")
plt.ylabel("Annual Salary")
plt.title("Annual salary by Age Group")
plt.show()

# %%
# decending/accending order plot
data.groupby("Age Ranges")["annual Salary"].mean().sort_values(ascending=False).plot(kind="bar")
plt.xlabel("Age Range")
plt.ylabel("Annual Salary")
plt.title("Annual salary by Age Group")
plt.show()

# %%
data.groupby("Age Ranges")["car purchase amount"].max().plot(kind="bar")
plt.title("Maximum amount sale for age group")
plt.xlabel("Age range")
plt.ylabel("Purchase amount")
plt.show()

# %%
# these are the two ways to represent the data 
data.groupby(["Age Ranges","gender2"])["annual Salary"].mean()
# Out:
# Age Ranges  gender2
# 20 - 30     Female     61656.174270
#             Male       61101.667473
# 30 - 40     Female     60474.781313
#             Male       63300.221926
# 40 - 50     Female     61293.340418
#             Male       63347.080071
# 50 - 60     Female     63165.221037
#             Male       62529.281355
# 60 - 70     Female     63876.773028
#             Male       53885.836882
# Name: annual Salary, dtype: float64

# %%
data.groupby(["gender2","Age Ranges"])["annual Salary"].mean()
# Out:
# gender2  Age Ranges
# Female   20 - 30       61656.174270
#          30 - 40       60474.781313
#          40 - 50       61293.340418
#          50 - 60       63165.221037
#          60 - 70       63876.773028
# Male     20 - 30       61101.667473
#          30 - 40       63300.221926
#          40 - 50       63347.080071
#          50 - 60       62529.281355
#          60 - 70       53885.836882
# Name: annual Salary, dtype: float64

# %%
data.groupby(["gender2","Age Ranges"])["car purchase amount"].mean()
# Out:
# gender2  Age Ranges
# Female   20 - 30       27417.853146
#          30 - 40       34698.012126
#          40 - 50       42136.093969
#          50 - 60       52224.305711
#          60 - 70       59429.713077
# Male     20 - 30       25277.462433
#          30 - 40       36033.521977
#          40 - 50       44183.213731
#          50 - 60       50086.066111
#          60 - 70       53534.350440
# Name: car purchase amount, dtype: float64

# %%
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount gender2 Age Ranges
# 0  238961.2505          35321.45877    Male    40 - 50
# ...

# %% [markdown]
# feature Engineering

# %%
X= data[["age", "annual Salary", "net worth"]]
Y= data[['car purchase amount']]

# %%
X
# Out:
#            age  annual Salary    net worth
# 0    41.851720    62812.09301  238961.2505
# 1    40.870623    66646.89292  530973.9078
# 2    43.152897    53798.55112  638467.1773
# 3    58.271369    79370.03798  548599.0524
# 4    57.313749    59729.15130  560304.0671
# ..         ...            ...          ...
# 495  41.462515    71942.40291  541670.1016
# 496  37.642000    56039.49793  360419.0988
# 497  53.943497    68888.77805  764531.3203
# 498  59.160509    49811.99062  337826.6382
# 499  46.731152    61370.67766  462946.4924
#
# [500 rows x 3 columns]

# %%
Y
# Out:
#      car purchase amount
# 0            35321.45877
# 1            45115.52566
# 2            42925.70921
# 3            67422.36313
# 4            55915.46248
# ..                   ...
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# 499          45107.22566
#
# [500 rows x 1 columns]

# %% [markdown]
# training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# here test size 0.2 means 80% of data is going in training set and 20 % is going in testing set

# %%
len(X_test)
# Out:
# 100

# %%
len(X_train)
# Out:
# 400

# %% [markdown]
# scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.31750906,  0.56981271, -0.05443099],
#        [ 0.06887839,  0.30562646,  0.86097347],
#        [-0.77523976,  1.0053835 ,  0.3082119 ],
#        ...,
#        [-0.90385443,  0.73377068, -0.75909936],
#        [-0.58216771,  0.86150898,  0.21777372],
#        [ 1.86050879, -0.01185151,  1.27455025]], shape=(400, 3))

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(Y_test,predictions)))
    print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(Y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predictions_linear_regression = lr.predict(X_test)

# %%
modelresults(predictions_linear_regression)
# Out:
# Mean absolute error on model is 2035.398722544608
# Root mean squared error on model is 2277.5165540479716

# %%
data["car purchase amount"].describe()
# Out:
# count      500.000000
# mean     44209.799218
# std      10773.178744
# min       9000.000000
# 25%      37629.896040
# 50%      43997.783390
# 75%      51254.709517
# max      80000.000000
# Name: car purchase amount, dtype: float64

# %%
# this is used to check the history and what we do in this notebook
# %hist
# Out:
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import numpy as np
# data = pd.read_csv("car_purchasing.csv", encoding="latin-1")
# data.head()
# data.info()
# data.shape
# data.columns
# data[['age','annual Salary', 'credit card debt', 'net worth','car purchase amount']].corr()["car purchase amount"].head(1)
# plt.scatter(data['age'],data['car purchase amount'])
# plt.title("Age and Purchase Amount")
# plt.xlabel("Age")
# plt.ylabel("Car Purchase Amount")
# plt.show
# plt.scatter(data['annual Salary'],data['car purchase amount'])
# plt.title("annual Salary and Purchase Amount")
# plt.xlabel("annual Salary")
# plt.ylabel("Car Purchase Amount")
# plt.show
# plt.scatter(data['net worth'],data['car purchase amount'])
# plt.title("net worth and Purchase Amount")
# plt.xlabel("net worth")
# plt.ylabel("Car Purchase Amount")
# plt.show
# plt.scatter(data['credit card debt'],data['car purchase amount'])
# ...

# %%
lr.coef_
# Out:
# array([[6523.85800368, 6453.15972173, 5068.62956837]])

# %%
# model 6836.2012466 * X1 + 6552.67720025 * X2 + 5083.15890356 * X3 = Target

# %%
X.columns
# Out:
# Index(['age', 'annual Salary', 'net worth'], dtype='object')

# %%
# 6836.2012466 * age + 6552.67720025 * annual Salary + 5083.15890356 * net worth = car purchase amount

# %%
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {"C":[0.01, 0.1, 0.5], "kernel": ["linear", "rbf", "poly"], "degree":[2, 3, 4]}

# %%
from sklearn.model_selection import GridSearchCV
gridsvr =GridSearchCV(svrmodel, param_gridsvr)

# %%
gridsvr.fit(X_train, Y_train)
# Out:
# c:\Project\Car sales Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Project\Car sales Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Project\Car sales Prediction\.venv\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
gridsvr.fit(X_train, Y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.01, 0.1, 0.5], 'degree': [2, 3, 4],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
predictions_gridsvr= gridsvr.predict(X_test)

# %%
modelresults(predictions_gridsvr)
# Out:
# Mean absolute error on model is 8030.8468692495335
# Root mean squared error on model is 10709.649228278338

# %%
gridsvr.best_params_
# Out:
# {'C': 0.5, 'degree': 2, 'kernel': 'linear'}

# %%
from sklearn.ensemble import RandomForestRegressor
rfrmodel = RandomForestRegressor()
param_gridrfr = {"max_depth": [5, 10, 15], "n_estimators": [2, 3, 4, 8, 9, 10]}

# %%
gridrfr = GridSearchCV(rfrmodel, param_gridrfr)

# %%
gridrfr.fit(X_train, Y_train.values.ravel())
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 8, 9, 10]})

# %%
predictionsrfr = gridrfr.predict(X_test)

# %%
modelresults(predictionsrfr)
# Out:
# Mean absolute error on model is 2796.4297998265624
# Root mean squared error on model is 3562.504232575151

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 9}

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
model = joblib.load("model.pkl")
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 model = joblib.load("model.pkl")
# ----> 2 model.predict()
#
# TypeError: LinearModel.predict() missing 1 required positional argument: 'X'
